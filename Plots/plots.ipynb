# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
o1_df = pd.read_csv('O1_time_data.csv', usecols=[1,2])
rapp_df = pd.read_csv('rAppTimeMetric.csv',usecols=[1,2,3,4,5,6,7,8,9])

# %%
df_a1_nexran = pd.read_csv('time_data_A1_nexRAN.csv',usecols=[1,2,3])
df_a1_nexran.head()
# Out:
#    S.No      Time          Call
# 0     0  0.006676       Add enb
# 1     1  0.002543  Create slice
# 2     2  0.003654    Bind slice
# 3     3  0.002858  Create slice
# 4     4  0.019528    Bind Slice

# %%
df_a1_nexran.describe()
# Out:
#              S.No        Time
# count  632.000000  632.000000
# mean   315.500000    0.003382
# std    182.586966    0.001411
# min      0.000000    0.000661
# 25%    157.750000    0.003556
# 50%    315.500000    0.003616
# 75%    473.250000    0.003658
# max    631.000000    0.021087

# %%
df_rapp_A1med = pd.read_csv('time_data_rapp_A1Med.csv',usecols=[1,2])
df_rapp_A1med.head()
# Out:
#    S.No      Time
# 0   0.0  0.792535
# 1   1.0  0.489381
# 2   2.0  0.768966
# 3   3.0  0.487190
# 4   4.0  0.747711

# %%
df_rapp_A1med.describe()
# Out:
#              S.No        Time
# count  102.000000  102.000000
# mean    50.500000    0.464184
# std     29.588849    0.277527
# min      0.000000    0.047156
# 25%     25.250000    0.282126
# 50%     50.500000    0.488681
# 75%     75.750000    0.584442
# max    101.000000    1.293669

# %%
# rapp_df.drop(['Unnamed: 0'],axis=1,inplace=True)
# o1_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
o1_df.describe()
# Out:
#                 S.No           Time
# count  700000.000000  700000.000000
# mean   349999.500000       0.001978
# std    202072.738554       0.003171
# min         0.000000       0.000927
# 25%    174999.750000       0.001563
# 50%    349999.500000       0.001717
# 75%    524999.250000       0.001898
# max    699999.000000       0.115905

# %%
# sns.boxplot(y=o1_df["Time"])

ax =sns.lineplot(data=o1_df[:100000], x="S.No", y="Time")
ax.set(xlabel='Iterations')
plt.savefig('o1_performance.png')
plt.show()

# %%
rapp_df.describe()
# Out:
#                 S.no           Time             S1             S2  \
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean   349999.500000       0.000428     149.975066     150.047450
# std    202072.738554       0.000122      86.889072      86.818275
# min         0.000000       0.000202       0.000000       0.000000
# 25%    174999.750000       0.000327      75.000000      75.000000
# 50%    349999.500000       0.000416     150.000000     150.000000
# 75%    524999.250000       0.000541     225.000000     225.000000
# max    699999.000000       0.001577     300.000000     300.000000
#
#                   S3  Proportion_S1  Proportion_S2  Proportion_S3
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean      150.055773      41.705514      40.742236      17.552250
# std        86.896676      21.509911      21.275167      21.117587
# min         0.000000       5.000000       3.000000       0.000000
# ...

# %%
ax = sns.lineplot(data=rapp_df[:50000], x="S.no", y="Time",hue='FirstResponder')
ax.set(xlabel='Iterations')
plt.savefig('rApp_performance.png')
plt.show()

# %%
ax = sns.scatterplot(data=df_a1_nexran[:100], x="S.No", y="Time",hue='Call')
ax.set(xlabel='Iterations')
# plt.savefig('rApp_performance.png')
plt.show()

# %%
ax = sns.lineplot(data=df_a1_nexran, x="S.No", y="Time",hue='Call')
ax.set(xlabel='Iterations')
# plt.savefig('rApp_performance.png')
plt.show()

# %%
ax = sns.lineplot(data=df_rapp_A1med, x="S.No", y="Time")
ax.set(xlabel='Iterations')
# plt.savefig('rApp_performance.png')
plt.show()

# %%
ax = sns.scatterplot(data=df_rapp_A1med, x="S.No", y="Time")
ax.set(xlabel='Iterations')
# plt.savefig('rApp_performance.png')
plt.show()

# %%
data = [0.001978,0.000428,0.464184,0.003382]
step = ['O1','rApp','raApp - A1 Med','A1 Med - nexRAN']
ax = sns.lineplot(y=data, x=step)
ax.set(xlabel='Component',ylabel='Time')
# plt.savefig('rApp_performance.png')
plt.show()
